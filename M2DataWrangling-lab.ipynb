# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
duplicate_rows = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")
# Out:
# Number of duplicate rows: 154

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %%
# Identify duplicate values in the 'Respondent' column
duplicate_respondents = df['Respondent'].duplicated()

# Count the number of duplicate values in the 'Respondent' column
num_duplicate_respondents = duplicate_respondents.sum()
num_duplicate_respondents
# Out:
# 154

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
duplicate_rows = df.duplicated().sum()
print(f"Number of duplicate rows after removal: {duplicate_rows}")
# Out:
# Number of duplicate rows after removal: 0

# %%
# Remove duplicate rows
df_cleaned = df.drop_duplicates()

# Count the number of rows in the cleaned dataset
num_rows_after_removal = df_cleaned.shape[0]
num_rows_after_removal
# Out:
# 11398

# %%
# Remove duplicate rows
df_cleaned = df.drop_duplicates()

# Count the number of unique values in the 'Respondent' column
num_unique_respondents = df_cleaned['Respondent'].nunique()
num_unique_respondents
# Out:
# 11398

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       542
# Ethnicity       675
# Dependents      140
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
missing_workloc = df['WorkLoc'].isnull().sum()
print(f"Number of missing rows in WorkLoc column: {missing_workloc}")
# Out:
# Number of missing rows in WorkLoc column: 32

# %%
# Remove duplicate rows
df_cleaned = df.drop_duplicates()

# Count the number of blank (or missing) rows in the 'EdLevel' column
num_blank_edlevel = df_cleaned['EdLevel'].isna().sum()
num_blank_edlevel
# Out:
# 112

# %%
# Remove duplicate rows
df_cleaned = df.drop_duplicates()

# Count the number of missing rows in the 'Country' column
num_missing_country = df_cleaned['Country'].isna().sum()
num_missing_country
# Out:
# 0

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
workloc_counts = df['WorkLoc'].value_counts()
print(workloc_counts)
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
most_frequent_workloc = df['WorkLoc'].mode()[0]
print(f"The most frequent value in WorkLoc column is: {most_frequent_workloc}")#
# Out:
# The most frequent value in WorkLoc column is: Office

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
df['WorkLoc'].fillna(df['WorkLoc'].mode()[0], inplace=True)

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
empty_workloc = df['WorkLoc'].isnull().sum()
print(f"Number of empty rows in WorkLoc column after imputation: {empty_workloc}")
# Out:
# Number of empty rows in WorkLoc column after imputation: 0

# %%
# Find the majority category in the 'Employment' column
majority_category = df['Employment'].mode()[0]
majority_category
# Out:
# 'Employed full-time'

# %%
# Find the category with the minimum number of rows in the 'UndergradMajor' column
min_category = df['UndergradMajor'].value_counts().idxmin()
min_category
# Out:
# 'A health science (ex. nursing, pharmacy, radiology)'

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
comp_freq_categories = df['CompFreq'].unique()
print("Categories in CompFreq column:")
print(comp_freq_categories)
# Out:
# Categories in CompFreq column:
# ['Yearly' 'Monthly' 'Weekly' nan]

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
def normalize_annual_compensation(row):
    if pd.isnull(row['CompFreq']) or pd.isnull(row['CompTotal']):
        return None
    elif row['CompFreq'] == 'Yearly':
        return row['CompTotal']
    elif row['CompFreq'] == 'Monthly':
        return row['CompTotal'] * 12
    elif row['CompFreq'] == 'Weekly':
        return row['CompTotal'] * 52
    else:
        return None

df['NormalizedAnnualCompensation'] = df.apply(normalize_annual_compensation, axis=1)

# %%
# Create the 'NormalizedAnnualCompensation' column
df['NormalizedAnnualCompensation'] = df.apply(lambda x: x['CompTotal'] * 12 if x['CompFreq'] == 'Monthly' 
                                               else x['CompTotal'] * 52 if x['CompFreq'] == 'Weekly' 
                                               else x['CompTotal'], axis=1)

# Now verify if the column was created successfully
df[['CompFreq', 'CompTotal', 'NormalizedAnnualCompensation']].head()
# Out:
#   CompFreq  CompTotal  NormalizedAnnualCompensation
# 0   Yearly    61000.0                       61000.0
# 1   Yearly   138000.0                      138000.0
# 2   Yearly    90000.0                       90000.0
# 3  Monthly    29000.0                      348000.0
# 4   Yearly    90000.0                       90000.0

# %%
# Count the number of unique values in the 'CompFreq' column
num_unique_compfreq = df['CompFreq'].nunique()
num_unique_compfreq
# Out:
# 3

# %%
# Remove duplicate rows
df_cleaned = df.drop_duplicates()

# Count the number of respondents being paid yearly
num_yearly_respondents = df_cleaned[df_cleaned['CompFreq'] == 'Yearly'].shape[0]
num_yearly_respondents
# Out:
# 6073

# %%
# Create a copy of the dataframe to avoid SettingWithCopyWarning
df_cleaned = df.drop_duplicates().copy()

# Define a function to normalize compensation
def normalize_compensation(row):
    if row['CompFreq'] == 'Yearly':
        return row['ConvertedComp']
    elif row['CompFreq'] == 'Monthly':
        return row['ConvertedComp'] * 12
    elif row['CompFreq'] == 'Weekly':
        return row['ConvertedComp'] * 52
    else:
        return None

# Apply the normalization function using .loc to avoid the warning
df_cleaned['NormalizedAnnualCompensation'] = df_cleaned.apply(normalize_compensation, axis=1)

# Calculate the median of the normalized annual compensation
median_normalized_compensation = df_cleaned['NormalizedAnnualCompensation'].median()
median_normalized_compensation
# Out:
# 118305.5

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
